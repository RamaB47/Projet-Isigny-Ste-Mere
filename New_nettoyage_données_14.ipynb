# %% [markdown]
# <a href="https://colab.research.google.com/github/RamaB47/Projet-Isigny-Ste-Mere/blob/main/New_nettoyage_donn%C3%A9es_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir('.'))  # Liste tous les fichiers visibles par Python ici
# Out:
# ['.config', 'Meteo14_ready.csv', 'Meteo14.csv', 'drive', '.ipynb_checkpoints', 'Meteo14_2.csv', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# 1. On charge les deux fichiers séparément (en spécifiant le bon séparateur, souvent ';' pour Météo France)
df1 = pd.read_csv('Meteo14.csv', sep=';')
df2 = pd.read_csv('Meteo14_2.csv', sep=';')

# %%
print(df1.columns.tolist())
# Out:
# ['NUM_POSTE', 'NOM_USUEL', 'LAT', 'LON', 'ALTI', 'AAAAMM', 'RR', 'QRR', 'NBRR', 'RR_ME', 'RRAB', 'QRRAB', 'RRABDAT', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJRR30', 'NBJRR50', 'NBJRR100', 'PMERM', 'QPMERM', 'NBPMERM', 'PMERMINAB', 'QPMERMINAB', 'PMERMINABDAT', 'TX', 'QTX', 'NBTX', 'TX_ME', 'TXAB', 'QTXAB', 'TXDAT', 'TXMIN', 'QTXMIN', 'TXMINDAT', 'NBJTX0', 'NBJTX25', 'NBJTX30', 'NBJTX35', 'NBJTXI20', 'NBJTXI27', 'NBJTXS32', 'TN', 'QTN', 'NBTN', 'TN_ME', 'TNAB', 'QTNAB', 'TNDAT', 'TNMAX', 'QTNMAX', 'TNMAXDAT', 'NBJTN5', 'NBJTN10', 'NBJTNI10', 'NBJTNI15', 'NBJTNI20', 'NBJTNS20', 'NBJTNS25', 'NBJGELEE', 'TAMPLIM', 'QTAMPLIM', 'TAMPLIAB', 'QTAMPLIAB', 'TAMPLIABDAT', 'NBTAMPLI', 'TM', 'QTM', 'NBTM', 'TMM', 'QTMM', 'NBTMM', 'NBJTMS24', 'TMMIN', 'QTMMIN', 'TMMINDAT', 'TMMAX', 'QTMMAX', 'TMMAXDAT', 'UNAB', 'QUNAB', 'UNABDAT', 'NBUN', 'UXAB', 'QUXAB', 'UXABDAT', 'NBUX', 'UMM', 'QUMM', 'NBUM', 'TSVM', 'QTSVM', 'NBTSVM', 'ETP', 'QETP', 'FXIAB', 'QFXIAB', 'DXIAB', 'QDXIAB', 'FXIDAT', 'NBJFF10', 'NBJFF1
# ...

# %%
import pandas as pd


# 2. On les colle l'un sous l'autre (l'en-tête du 2e est géré automatiquement, pas de doublon !)
df_total = pd.concat([df1, df2], ignore_index=True)

# 3. On nettoie les espaces cachés dans les noms de colonnes
df_total.columns = df_total.columns.str.strip()

# 4. On applique votre filtre pour ne garder que vos 9 colonnes
colonnes_a_garder = ["NUM_POSTE", "NOM_USUEL", "RR", "AAAAMM", "NBRR", "TX","TN", "TM"]
df_final = df_total[colonnes_a_garder]

# On regarde le résultat
df_final.head()
# Out:
#    NUM_POSTE  NOM_USUEL    RR  AAAAMM  NBRR  TX  TN  TM
# 0   14016001  ANNEBAULT  24.1  195001  31.0 NaN NaN NaN
# 1   14016001  ANNEBAULT  84.3  195002  28.0 NaN NaN NaN
# 2   14016001  ANNEBAULT  27.2  195003  31.0 NaN NaN NaN
# 3   14016001  ANNEBAULT  90.4  195004  30.0 NaN NaN NaN
# 4   14016001  ANNEBAULT  42.9  195005  31.0 NaN NaN NaN

# %%
print(df_final.head)
# Out:
# <bound method NDFrame.head of        NUM_POSTE        NOM_USUEL    RR  AAAAMM  NBRR    TX    TN    TM
# 0       14016001        ANNEBAULT  24.1  195001  31.0   NaN   NaN   NaN
# 1       14016001        ANNEBAULT  84.3  195002  28.0   NaN   NaN   NaN
# 2       14016001        ANNEBAULT  27.2  195003  31.0   NaN   NaN   NaN
# 3       14016001        ANNEBAULT  90.4  195004  30.0   NaN   NaN   NaN
# 4       14016001        ANNEBAULT  42.9  195005  31.0   NaN   NaN   NaN
# ...          ...              ...   ...     ...   ...   ...   ...   ...
# 30789   14762004  VIRE HIPPODROME  44.6  202603  31.0  14.6   3.5   9.1
# 30790   14762004  VIRE HIPPODROME   5.2  202604  30.0  18.9   5.0  12.0
# 30791   14762004  VIRE HIPPODROME  87.7  202605  31.0  21.6   9.9  15.7
# 30792   14762004  VIRE HIPPODROME  38.4  202606  30.0  26.5  13.3  19.9
# 30793   14762004  VIRE HIPPODROME   0.0  202607   1.0  22.6  12.4  17.5
#
# [30794 rows x 8 columns]>

# %%
print(len(df_final))
print(df_final.index)
# Out:
# 30794
# RangeIndex(start=0, stop=30794, step=1)

# %%
print(df_final.columns)
# Out:
# Index(['NUM_POSTE', 'NOM_USUEL', 'RR', 'AAAAMM', 'NBRR', 'TX', 'TN', 'TM'], dtype='object')

# %%
df_englesqueville = df_final[df_final["NOM_USUEL"] == "ENGLESQUEVILLE"]

# %%
print(df_englesqueville.shape)
# Out:
# (822, 8)

# %%
print(df_englesqueville.tail(30))
# Out:
#        NUM_POSTE       NOM_USUEL     RR  AAAAMM  NBRR    TX    TN    TM
# 8360    14239001  ENGLESQUEVILLE  114.2  202402  29.0  12.1   7.4   9.7
# 8361    14239001  ENGLESQUEVILLE   56.7  202403  31.0  13.1   5.7   9.4
# 8362    14239001  ENGLESQUEVILLE   41.8  202404  30.0  15.3   7.5  11.4
# 8363    14239001  ENGLESQUEVILLE   68.7  202405  31.0  17.7  10.2  13.9
# 8364    14239001  ENGLESQUEVILLE   17.0  202406  30.0  19.3  10.7  15.0
# 8365    14239001  ENGLESQUEVILLE   40.5  202407  31.0  22.0  13.5  17.7
# 8366    14239001  ENGLESQUEVILLE   41.2  202408  31.0  23.4  14.1  18.8
# 8367    14239001  ENGLESQUEVILLE  124.4  202409  30.0  18.8  12.6  15.7
# 8368    14239001  ENGLESQUEVILLE   73.9  202410  31.0  17.4  10.4  13.9
# 8369    14239001  ENGLESQUEVILLE   84.7  202411  30.0  12.4   7.5   9.9
# 8370    14239001  ENGLESQUEVILLE   60.0  202412  31.0   9.9   5.6   7.8
# 30547   14239001  ENGLESQUEVILLE  189.5  202501  31.0   8.3   2.2   5.3
# ...

# %%
value = pd.NaT
print(pd.isna(value))
# Out:
# True

# %%
val_nat = df_englesqueville[df_englesqueville['AAAAMM'].isna()]
print(val_nat.index)
# Out:
# Index([], dtype='int64')

# %%
from datetime import datetime

# %%
# Convertir proprement la colonne de dates en texte (string) via son nom
df_englesqueville['AAAAMM'] = df_englesqueville['AAAAMM'].astype(str)
# Out:
# /tmp/ipykernel_20022/1145030480.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_englesqueville['AAAAMM'] = df_englesqueville['AAAAMM'].astype(str)

# %%
df_englesqueville.to_csv("Meteo14_ready.csv")

# %%
df_ready = df_englesqueville.iloc[:, 5]
