# %% [markdown]
# <a href="https://colab.research.google.com/github/RamaB47/Projet-Isigny-Ste-Mere/blob/main/fichier_meteo_final_Isigny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = "Meteo14_ready.csv"
df2 = "Meteo50_ready.csv"

# %%
station1 = pd.read_csv(df1)

# %%
print(station1)
# Out:
#     Unnamed: 0  NUM_POSTE       NOM_USUEL     RR  AAAAMM  NBRR    TX    TN  \
# 0         8311   14239001  ENGLESQUEVILLE   77.8  202001  31.0  10.4   5.2
# 1         8312   14239001  ENGLESQUEVILLE  143.6  202002  29.0  11.4   5.8
# 2         8313   14239001  ENGLESQUEVILLE   60.9  202003  31.0  11.3   5.5
# 3         8314   14239001  ENGLESQUEVILLE   43.1  202004  30.0  15.1   8.0
# 4         8315   14239001  ENGLESQUEVILLE   24.5  202005  31.0  16.7   9.4
# ..         ...        ...             ...    ...     ...   ...   ...   ...
# 74       30561   14239001  ENGLESQUEVILLE   26.6  202603  31.0  13.5   6.4
# 75       30562   14239001  ENGLESQUEVILLE    2.8  202604  30.0  16.2   8.5
# 76       30563   14239001  ENGLESQUEVILLE   42.3  202605  31.0  19.5  11.3
# 77       30564   14239001  ENGLESQUEVILLE   39.4  202606  30.0  23.3  13.4
# 78       30565   14239001  ENGLESQUEVILLE    0.0  202607   1.0  23.6  12.9
#
#       TM
# 0    7.8
# 1    8.6
# 2    8.4
# 3   11.6
# 4   13.0
# ...

# %%
station2 = pd.read_csv(df2)

# %%
print(station2)
# Out:
#     Unnamed: 0  NUM_POSTE        NOM_USUEL     RR  AAAAMM  NBRR    TX    TN  \
# 0        25762   50509002  STE MARIE DU MO   77.0  202001  31.0  10.7   4.5
# 1        25763   50509002  STE MARIE DU MO  146.4  202002  29.0  11.7   5.9
# 2        25764   50509002  STE MARIE DU MO   81.0  202003  31.0  11.5   5.5
# 3        25765   50509002  STE MARIE DU MO   40.0  202004  30.0  15.0   7.4
# 4        25766   50509002  STE MARIE DU MO   32.5  202005  31.0  16.7   9.3
# ..         ...        ...              ...    ...     ...   ...   ...   ...
# 74       32318   50509002  STE MARIE DU MO   23.4  202603  31.0  13.3   5.9
# 75       32319   50509002  STE MARIE DU MO    7.4  202604  30.0  15.8   8.2
# 76       32320   50509002  STE MARIE DU MO   33.9  202605  31.0  18.9  10.7
# 77       32321   50509002  STE MARIE DU MO   42.1  202606  30.0  21.8  13.5
# 78       32322   50509002  STE MARIE DU MO    0.0  202607   1.0  23.8  13.6
#
#       TM
# 0    7.6
# 1    8.8
# 2    8.5
# 3   11.2
# ...

# %%
pd.concat([station1, station2], ignore_index=False)
# Out:
#     Unnamed: 0  NUM_POSTE        NOM_USUEL     RR  AAAAMM  NBRR    TX    TN  \
# 0         8311   14239001   ENGLESQUEVILLE   77.8  202001  31.0  10.4   5.2
# 1         8312   14239001   ENGLESQUEVILLE  143.6  202002  29.0  11.4   5.8
# 2         8313   14239001   ENGLESQUEVILLE   60.9  202003  31.0  11.3   5.5
# 3         8314   14239001   ENGLESQUEVILLE   43.1  202004  30.0  15.1   8.0
# 4         8315   14239001   ENGLESQUEVILLE   24.5  202005  31.0  16.7   9.4
# ..         ...        ...              ...    ...     ...   ...   ...   ...
# 74       32318   50509002  STE MARIE DU MO   23.4  202603  31.0  13.3   5.9
# 75       32319   50509002  STE MARIE DU MO    7.4  202604  30.0  15.8   8.2
# 76       32320   50509002  STE MARIE DU MO   33.9  202605  31.0  18.9  10.7
# 77       32321   50509002  STE MARIE DU MO   42.1  202606  30.0  21.8  13.5
# 78       32322   50509002  STE MARIE DU MO    0.0  202607   1.0  23.8  13.6
#
#       TM
# 0    7.8
# 1    8.6
# 2    8.4
# 3   11.6
# ...

# %%
fichier_final = pd.concat([station1, station2], ignore_index=False)

# %%
fichier_final.to_csv("fichier_meteo_final.csv")

# %%
df = pd.read_csv("fichier_meteo_final.csv")

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'NUM_POSTE', 'NOM_USUEL', 'RR', 'AAAAMM',
#        'NBRR', 'TX', 'TN', 'TM'],
#       dtype='object')

# %%
tab_final = df.groupby("AAAAMM")[["RR", "NBRR", "TX", "TN", "TM"]].mean()

# %%
print(tab_final)
# Out:
#             RR  NBRR     TX     TN     TM
# AAAAMM
# 202001   77.40  31.0  10.55   4.85   7.70
# 202002  145.00  29.0  11.55   5.85   8.70
# 202003   70.95  31.0  11.40   5.50   8.45
# 202004   41.55  30.0  15.05   7.70  11.40
# 202005   28.50  31.0  16.70   9.35  13.00
# ...        ...   ...    ...    ...    ...
# 202603   25.00  31.0  13.40   6.15   9.75
# 202604    5.10  30.0  16.00   8.35  12.20
# 202605   38.10  31.0  19.20  11.00  15.10
# 202606   40.75  30.0  22.55  13.45  18.05
# 202607    0.00   1.0  23.70  13.25  18.50
#
# [79 rows x 5 columns]

# %%
tab_final.to_csv("fichier_meteo_final.csv")
